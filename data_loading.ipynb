# %% [markdown]
# # SQLite

# %%
# 导入必需的库
import sqlite3
import pandas as pd

# 数据库连接
DB_PATH = "todoapp.sqlite"  # 确保数据库路径正确
con = sqlite3.connect(DB_PATH)

# 查询数据库中的所有任务
query = "SELECT * FROM tasks"
tasks_df = pd.read_sql_query(query, con)

# 显示数据表格
tasks_df
# Out:
#     id              name              description  is_done
# 0    1                12                      212        0
# 1    2                12                      212        0
# 2    3                12                        3        0
# 3    4              2123                    31212        0
# 4    5             12123                   312122        0
# 5    6             12123               3121222121        0
# 6    7           1212332               3121222121        0
# 7    8              jue1               3121222121        0
# 8    9              jue1                   21d343        0
# 9   10               243                   334444        0
# 10  11               243                   334444        0
# 11  12               243            3344449901001        0
# 12  13               243        33444499011314001        0
# 13  14               243    334444990113140013143        0
# 14  15             12121                  3232323        0
# ...
